# %%
from Objects.Transformations import *
from Objects.WSBM import *
from Objects.TWSBMInstance import *

from Computation.Computation import *
from Computation.ExtraMetrics import *

from Plotting.Plotting import *
from Plotting.ArtisticPlotting import *

# %%
p22 = 'fixed'

for batch in range(0, 2):
	for rho, pi, model in RHOS_PIS_MODELS:
		print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}")
		simulate_in_grid(100, batch, 1, model, (rho, pi), transformations=TRANSFORMS, p22=p22)
# Out:
# Simulating for rho=0.25, pi=0.1, model=betaWSBM
# Simulation: 100%|██████████| 16/16 [00:02<00:00,  5.45it/s]
# Simulating for rho=0.25, pi=0.1, model=lognormWSBM
# Simulation: 100%|██████████| 16/16 [00:04<00:00,  3.97it/s]
# Simulating for rho=0.25, pi=0.5, model=betaWSBM
# Simulation: 100%|██████████| 16/16 [00:01<00:00,  8.47it/s]
# Simulating for rho=0.25, pi=0.5, model=lognormWSBM
# Simulation: 100%|██████████| 16/16 [00:03<00:00,  5.20it/s]
# Simulating for rho=0.5, pi=0.1, model=betaWSBM
# Simulation: 100%|██████████| 16/16 [00:02<00:00,  5.85it/s]
# Simulating for rho=0.5, pi=0.1, model=lognormWSBM
# Simulation: 100%|██████████| 16/16 [00:03<00:00,  4.61it/s]
# Simulating for rho=0.5, pi=0.5, model=betaWSBM
# Simulation: 100%|██████████| 16/16 [00:02<00:00,  6.98it/s]
# Simulating for rho=0.5, pi=0.5, model=lognormWSBM
# Simulation: 100%|██████████| 16/16 [00:02<00:00,  5.41it/s]

# %%
N = 100
R = 100
for model in MODELS:
    print(f"Simulating for varying_param = rho")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            varying_param = 'rho',
                                            varying_param_bounds = (0, 0.5))
    print(f"Simulating for varying_param = pi")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            varying_param = 'pi',
                                            varying_param_bounds = (0.01, 0.5))
    print(f"Simulating for varying_param = p11")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            varying_param = 'p11',
                                            varying_param_bounds = (0.01, 1))
    print(f"Simulating for varying_param = p12")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            varying_param = 'p12',
                                            varying_param_bounds = (0.01, 1))
    print(f"Simulating for varying_param = PowerTransform")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            t = PowerTransform(1),
                                            varying_param = PowerTransform,
                                            varying_param_bounds = (0.5, 2))
    print(f"Simulating for varying_param = QuantileTransform")
    simulate_in_line_with_one_varying_param(N = N, R = R,
                                            model = model,
                                            t = QuantileTransform(0.5),
                                            varying_param = QuantileTransform,
                                            varying_param_bounds = (0, 0.99))
# Out:
# Simulating for varying_param = QantileTransform
# Using 3 threads (out of 4)
# Simulation: 100%|██████████| 3/3 [00:00<00:00, 419.67it/s]
# Simulating for varying_param = QantileTransform
# Using 3 threads (out of 4)
# Simulation: 100%|██████████| 3/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 598, in __call__
# ...
