# %%
from Objects.Transformations import *
from Objects.WSBM import *
from Objects.TWSBMInstance import *

from Computation.Computation import *
from Computation.ExtraMetrics import *

from Plotting.Plotting import *
from Plotting.ArtisticPlotting import *

# %%
for rho, pi, model in RHOS_PIS_MODELS:
	print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}")
	simulate_in_grid(4, 0, 2, model, (rho, pi), transformations=TRANSFORMS)

# %%
for emb_mode, p22 in product(EMB_MODES[:1], P22S[1:]):
	print(f"Simulating for emb_mode = {emb_mode}, p22 = {p22}")
	for rho, pi, model in RHOS_PIS_MODELS:
		for p in linspace_exclusive(0, 1, 4):
			print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}, p11={p}")
			simulate_in_line(100, 20, model, (rho, pi), transformations=TRANSFORMS, 
					p11 = p, p22 = p22, emb_mode = emb_mode)
			print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}, p12={p}")
			#simulate_in_line(100, 20, model, (rho, pi), transformations=TRANSFORMS, 
			#		p12 = p, p22 = p22, emb_mode = emb_mode)
# Out:
# Simulating for emb_mode = sqrt-scaled, p22 = p11
# Simulating for rho=0.25, pi=0.1, model=betaWSBM, p11=0.2
# Progress: 1/2000 (0.1%). Elapsed: 00:00:05. ETA: 02:59:59.
# Progress: 2/2000 (0.1%). Elapsed: 00:00:08. ETA: 02:15:41.
# Progress: 3/2000 (0.1%). Elapsed: 00:00:10. ETA: 01:52:35.
# Progress: 4/2000 (0.2%). Elapsed: 00:00:12. ETA: 01:42:23.
# Progress: 5/2000 (0.2%). Elapsed: 00:00:14. ETA: 01:38:22.
# Progress: 6/2000 (0.3%). Elapsed: 00:00:17. ETA: 01:38:05.
# Progress: 7/2000 (0.4%). Elapsed: 00:00:20. ETA: 01:35:15.
# Progress: 8/2000 (0.4%). Elapsed: 00:00:22. ETA: 01:31:44.
# Progress: 9/2000 (0.4%). Elapsed: 00:00:24. ETA: 01:29:26.
# Progress: 10/2000 (0.5%). Elapsed: 00:00:26. ETA: 01:27:36.
# Progress: 11/2000 (0.5%). Elapsed: 00:00:28. ETA: 01:24:34.
# Progress: 12/2000 (0.6%). Elapsed: 00:00:30. ETA: 01:22:52.
# Progress: 13/2000 (0.7%). Elapsed: 00:00:32. ETA: 01:23:24.
# Progress: 14/2000 (0.7%). Elapsed: 00:00:34. ETA: 01:22:01.
# Progress: 15/2000 (0.8%). Elapsed: 00:00:36. ETA: 01:20:33.
# Progress: 16/2000 (0.8%). Elapsed: 00:00:39. ETA: 01:21:01.
# Progress: 17/2000 (0.9%). Elapsed: 00:00:41. ETA: 01:20:02.
# Progress: 18/2000 (0.9%). Elapsed: 00:00:43. ETA: 01:20:05.
# Progress: 19/2000 (0.9%). Elapsed: 00:00:46. ETA: 01:20:43.
# Progress: 20/2000 (1.0%). Elapsed: 00:00:48. ETA: 01:19:28.
# Progress: 21/2000 (1.1%). Elapsed: 00:00:50. ETA: 01:19:40.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 for p in linspace_exclusive(0, 1, 4):
#       5 	print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}, p11={p}")
# ----> 6 	simulate_in_line(100, 20, model, (rho, pi), transformations=TRANSFORMS,
#       7 			p11 = p, p22 = p22, emb_mode = emb_mode)
#       8 	print(f"Simulating for rho={rho}, pi={pi}, model={model.__name__}, p12={p}")
#       9 	#simulate_in_line(100, 20, model, (rho, pi), transformations=TRANSFORMS,
#      10 	#		p12 = p, p22 = p22, emb_mode = emb_mode)
#
# File c:\Users\Nicol\Documents\EPFL\MA6\Project\Code\Computation\Computation.py:86, in simulate_in_line(N, rep, model, model_params, transformations, p11, p12, p22, emb_mode)
#      84 A, Z = m(seed = seed)
#      85 for t in transformations:
# ---> 86 	G = TWSBMInstance(model = m, transformation = t, A = t(A), Z = Z, emb_mode = emb_mode)
#      87 	metrics[f'{t.id}_C_true'][i, j]  = G.C_true
#      88 	metrics[f'{t.id}_C_graph'][i, j] = G.C_graph
#
# File c:\Users\Nicol\Documents\EPFL\MA6\Project\Code\Objects\TWSBMInstance.py:41, in TWSBMInstance.__init__(self, model, transformation, A, Z, seed, emb_mode)
#      38 self.model_name = model.name
#      39 self.transform_name = transformation.name
# ---> 41 self.X = self.__spectral_embedding(self.A, mode = emb_mode)
#      42 self.Z_hat, self.M, self.Σ = self.__fit_GMM(self.X)
#      44 if self.model is not None:
#
# File c:\Users\Nicol\Documents\EPFL\MA6\Project\Code\Objects\TWSBMInstance.py:76, in TWSBMInstance.__spectral_embedding(self, A, mode, d)
#      75 def __spectral_embedding(self, A, mode, d=2):
# ---> 76 	vals, vecs = eigsh(A, k=d, which='LM')
#      77 	if mode == 'sqrt-scaled':
#      78 		return vecs * np.sqrt(np.abs(vals))
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1700, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1698 with _ARPACK_LOCK:
#    1699     while not params.converged:
# -> 1700         params.iterate()
#    1702     return params.extract(return_eigenvectors)
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:549, in _SymmetricArpackParams.iterate(self)
#     546 elif self.ido == 1:
#     547     # compute y = Op*x
#     548     if self.mode == 1:
# --> 549         self.workd[yslice] = self.OP(self.workd[xslice])
#     550     elif self.mode == 2:
#     551         self.workd[xslice] = self.OPb(self.workd[xslice])
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_interface.py:236, in LinearOperator.matvec(self, x)
#     233 if x.shape != (N,) and x.shape != (N,1):
#     234     raise ValueError('dimension mismatch')
# --> 236 y = self._matvec(x)
#     238 if isinstance(x, np.matrix):
#     239     y = asmatrix(y)
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_interface.py:203, in LinearOperator._matvec(self, x)
#     193 def _matvec(self, x):
#     194     """Default matrix-vector multiplication handler.
#     195
#     196     If self is a linear operator of shape (M, N), then this method will
#    (...)
#     201     will define matrix-vector multiplication as well.
#     202     """
# --> 203     return self.matmat(x.reshape(-1, 1))
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_interface.py:340, in LinearOperator.matmat(self, X)
#     337     raise ValueError(f'dimension mismatch: {self.shape}, {X.shape}')
#     339 try:
# --> 340     Y = self._matmat(X)
#     341 except Exception as e:
#     342     if issparse(X) or is_pydata_spmatrix(X):
#
# File c:\Users\Nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\linalg\_interface.py:800, in MatrixLinearOperator._matmat(self, X)
#     799 def _matmat(self, X):
# --> 800     return self.A.dot(X)
#
# KeyboardInterrupt:
